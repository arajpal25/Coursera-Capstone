# %% [markdown]
# # importing the libraries

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
from  bs4 import BeautifulSoup 
import pandas as pd

# %% [markdown]
# # Storing the table of wikipedia page to dataframe

# %%
import requests
import lxml.html as lh
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    
    col.append((name,[]))
    
print(col)

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
   
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=3:
        break
   
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %% [markdown]
# # replacing the newline character and displaying th dataframe

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)
df = df.replace('\n','', regex=True)
df.head()

# %% [markdown]
# # printing the number of columns

# %%
df= df.drop(180)
for col in df.columns:
    print (col)

# %% [markdown]
# # replacing the column names new line character

# %%
df.columns=df.columns.str.replace('\n','')

# %%
df.dtypes

# %% [markdown]
# # assigning a new dataframe where Not assigned borough is not present

# %%
df_upd= df[df['Neighborhood'] !='']
df_upd.head(12)

# %% [markdown]
# # reset the index

# %%
df_upd= df_upd.reset_index(drop=True)

# %% [markdown]
# # The data given in wiki already has been grouped per postal code, hence modifying the GUI part to show as its there in coursera assignment

# %%
df_upd = df_upd.replace('/',',', regex=True)

# %%
df_upd.head(12)

# %% [markdown]
# # Shape of the dataframe

# %%
df_upd.shape

# %% [markdown]
# # Part 2 of the assignment begins here

# %%
dfOfLatLong = pd.read_csv('http://cocl.us/Geospatial_data')

# %%
dfOfLatLong= dfOfLatLong.rename(columns={'Postal Code' : 'Postal code'})
dfOfLatLong
# Out:
#     Postal code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# 24          M2R  43.782736 -79.442259
# 25          M3A  43.753259 -79.329656
# 26          M3B  43.745906 -79.352188
# 27          M3C  43.725900 -79.340923
# 28          M3H  43.754328 -79.442259
# 29          M3J  43.767980 -79.487262
# ..          ...        ...        ...
# 73          M6C  43.693781 -79.428191
# 74          M6E  43.689026 -79.453512
# 75          M6G  43.669542 -79.422564
# 76          M6H  43.669005 -79.442259
# 77          M6J  43.647927 -79.419750
# 78          M6K  43.636847 -79.428191
# 79          M6L  43.713756 -79.490074
# 80          M6M  43.691116 -79.476013
# 81          M6N  43.673185 -79.487262
# 82          M6P  43.661608 -79.464763
# 83          M6R  43.648960 -79.456325
# 84          M6S  43.651571 -79.484450
# 85          M7A  43.662301 -79.389494
# 86          M7R  43.636966 -79.615819
# 87          M7Y  43.662744 -79.321558
# 88          M8V  43.605647 -79.501321
# 89          M8W  43.602414 -79.543484
# 90          M8X  43.653654 -79.506944
# 91          M8Y  43.636258 -79.498509
# 92          M8Z  43.628841 -79.520999
# 93          M9A  43.667856 -79.532242
# 94          M9B  43.650943 -79.554724
# 95          M9C  43.643515 -79.577201
# 96          M9L  43.756303 -79.565963
# 97          M9M  43.724766 -79.532242
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %% [markdown]
# # The CSV file with Data is uploaded in Data frame . time to merge the two dataframes to form one dtaframe for data.

# %%
dfOfLatLong = pd.merge(df_upd, dfOfLatLong, on="Postal code")

# %%
dfOfLatLong.head(30)

# %% [markdown]
# # Part 3 of the assignment begins

# %%
LATITUDE= 43.706748
LONGITUDE = -79.594054
CLIENT_ID = 'PJHVABWBETOR53I2N3GKF1XVZZANCEYSNY5HK2IZC2LNY1BB'
CLIENT_SECRET = 'O0JDJQJPH04WFFHQN05VVEKTEA3WDY3NCIDCTUWIWK4XLBWI'
VERSION = '20200427'
LIMIT = 30
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&limit={}'.format(CLIENT_ID,CLIENT_SECRET,LATITUDE,LONGITUDE,VERSION,LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=PJHVABWBETOR53I2N3GKF1XVZZANCEYSNY5HK2IZC2LNY1BB&client_secret=O0JDJQJPH04WFFHQN05VVEKTEA3WDY3NCIDCTUWIWK4XLBWI&ll=43.706748,-79.594054&v=20200427&limit=30'

# %% [markdown]
# # Importing libraries

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
import requests
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     certifi-2020.4.5.1         |   py36h9f0ad1d_0         151 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.1.1-0                    --> 2020.4.5.1-hecc5488_0     conda-forge
#     certifi:         2020.4.5.1-py36_0             --> 2020.4.5.1-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1f-h7b6447c_0             --> 1.1.1g-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# certifi-2020.4.5.1   | 151 KB    | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# ca-certificates-2020 | 146 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.1.0-py_1 conda-forge
#     branca:  0.4.0-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ea6db47dd0f850022ea51ef'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'suggestedRadius': 3378,
#   'headerLocation': 'Toronto',
#   'headerFullLocation': 'Toronto',
#   'headerLocationGranularity': 'city',
#   'totalResults': 182,
#   'suggestedBounds': {'ne': {'lat': 43.736973762936266,
#     'lng': -79.55154379114254},
#    'sw': {'lat': 43.67489961948987, 'lng': -79.63519857285468}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba50113f964a52018cf38e3',
#        'name': 'Fortinos',
#        'location': {'address': '330 Queens Plate Dr',
#         'crossStreet': 'at Hwy 27',
#         'lat': 43.721438,
#         'lng': -79.596291,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.721438,
#           'lng': -79.596291}],
#         'distance': 1645,
#         'postalCode': 'M9W 7J7',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['330 Queens Plate Dr (at Hwy 27)',
#          'Etobicoke ON M9W 7J7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba50113f964a52018cf38e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5f8a3df964a52062c029e3',
#        'name': 'Mandarin Buffet',
#        'location': {'address': '200 Queens Plate Dr',
#         'crossStreet': 'at Hwy 27',
#         'lat': 43.7203596,
#         'lng': -79.5943875,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7203596,
#           'lng': -79.5943875}],
#         'distance': 1515,
#         'postalCode': 'M9W 6Y9',
#         'cc': 'CA',
#         'city': 'Rexdale',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['200 Queens Plate Dr (at Hwy 27)',
#          'Rexdale ON M9W 6Y9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5f8a3df964a52062c029e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9924aaf964a5205e6435e3',
#        'name': 'Golden Asian',
#        'location': {'address': '123 - #7 Rexdale Blvd.',
#         'lat': 43.71124779631982,
#         'lng': -79.56596849779808,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.71124779631982,
#           'lng': -79.56596849779808}],
#         'distance': 2314,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['123 - #7 Rexdale Blvd.',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9924aaf964a5205e6435e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad7719cf964a520870a21e3',
#        'name': 'The Keg Steakhouse + Bar - Dixon Road',
#        'location': {'address': '927 Dixon Road',
#         'lat': 43.68632856455964,
#         'lng': -79.59735263847949,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.68632856455964,
#           'lng': -79.59735263847949}],
#         'distance': 2288,
#         'postalCode': 'M9W 1J8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['927 Dixon Road',
#          'Toronto ON M9W 1J8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad7719cf964a520870a21e3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dad993e6e81d745d744c5fb',
#        'name': 'Tre Rose Bakery',
#        'location': {'address': '2098 Kipling avenue',
#         'crossStreet': 'Kipling and rexdale',
#         'lat': 43.7164913472275,
#         'lng': -79.56928808308881,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7164913472275,
#           'lng': -79.56928808308881}],
#         'distance': 2268,
#         'postalCode': 'M9W 4K5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2098 Kipling avenue (Kipling and rexdale)',
#          'Toronto ON M9W 4K5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dad993e6e81d745d744c5fb-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e295cc02271752a459d81e1',
#        'name': 'Alt Hotel Toronto Airport',
#        'location': {'address': '6080, Viscount Road',
#         'lat': 43.689702363851865,
#         'lng': -79.61466905311681,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.689702363851865,
#           'lng': -79.61466905311681}],
#         'distance': 2520,
#         'postalCode': 'L4V 0A1',
#         'cc': 'CA',
#         'city': 'Mississauga',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['6080, Viscount Road',
#          'Mississauga ON L4V 0A1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e295cc02271752a459d81e1-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a06504192e7a97476fe618e',
#        'name': "Ruth's Chris Steak House",
#        'location': {'address': '970 Dixon Rd, Building B',
#         'lat': 43.68726356398384,
#         'lng': -79.60000678896898,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.68726356398384,
#           'lng': -79.60000678896898}],
#         'distance': 2221,
#         'postalCode': 'M9W 1J9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['970 Dixon Rd, Building B',
#          'Toronto ON M9W 1J9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a06504192e7a97476fe618e-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50a18bdbe4b057cac5b78d4b',
#        'name': 'Chop Steakhouse Bar',
#        'location': {'address': '801 Dixon Rd',
#         'crossStreet': 'at Atwell Dr',
#         'lat': 43.686931677370595,
#         'lng': -79.58911685017826,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.686931677370595,
#           'lng': -79.58911685017826}],
#         'distance': 2241,
#         'postalCode': 'M9W 1J5',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['801 Dixon Rd (at Atwell Dr)',
#          'Etobicoke ON M9W 1J5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50a18bdbe4b057cac5b78d4b-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5d083ef964a520bd4f29e3',
#        'name': 'Ginko',
#        'location': {'address': '655 Dixon Road',
#         'lat': 43.68919348672182,
#         'lng': -79.57844087379546,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.68919348672182,
#           'lng': -79.57844087379546}],
#         'distance': 2323,
#         'postalCode': 'M9W 1J4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['655 Dixon Road',
#          'Toronto ON M9W 1J4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5d083ef964a520bd4f29e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1ccf5ceac020a12c0d47c2',
#        'name': "Wally's Grill",
#        'location': {'address': '123 Rexdale Blvd.',
#         'crossStreet': 'at Kipling Ave.',
#         'lat': 43.71073634197878,
#         'lng': -79.56588067588311,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.71073634197878,
#           'lng': -79.56588067588311}],
#         'distance': 2310,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['123 Rexdale Blvd. (at Kipling Ave.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1ccf5ceac020a12c0d47c2-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b583fbdf964a5208d4f28e3',
#        'name': 'Hilton Garden Inn',
#        'location': {'address': '3311 Caroga Dr',
#         'lat': 43.6899014,
#         'lng': -79.6064597,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6899014,
#           'lng': -79.6064597}],
#         'distance': 2124,
#         'postalCode': 'L4V 1A3',
#         'cc': 'CA',
#         'city': 'Mississauga',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['3311 Caroga Dr',
#          'Mississauga ON L4V 1A3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b583fbdf964a5208d4f28e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b462be3f964a520ec1826e3',
#        'name': 'Fitness 365',
#        'location': {'address': '40 Ronson Drive, Unit 2',
#         'crossStreet': 'Kipling Ave.',
#         'lat': 43.6984228592084,
#         'lng': -79.56421141496305,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6984228592084,
#           'lng': -79.56421141496305}],
#         'distance': 2574,
#         'postalCode': 'M9W 1B3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['40 Ronson Drive, Unit 2 (Kipling Ave.)',
#          'Toronto ON M9W 1B3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b462be3f964a520ec1826e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af5e391f964a5205bfe21e3',
#        'name': 'Humber Arboretum',
#        'location': {'address': '205 Humber College Blvd',
#         'crossStreet': 'at Finch & Hwy 27',
#         'lat': 43.72465342539647,
#         'lng': -79.60800647735596,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.72465342539647,
#           'lng': -79.60800647735596}],
#         'distance': 2287,
#         'postalCode': 'M9W 5L7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['205 Humber College Blvd (at Finch & Hwy 27)',
#          'Toronto ON M9W 5L7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d15a941735',
#          'name': 'Garden',
#          'pluralName': 'Gardens',
#          'shortName': 'Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af5e391f964a5205bfe21e3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae8b77cf964a520a8b121e3',
#        'name': "Chubby's Fish N' Chips",
#        'location': {'address': '2290 Islington Ave.',
#         'crossStreet': 'Rexdale Blvd.',
#         'lat': 43.7151901026172,
#         'lng': -79.55534628122035,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7151901026172,
#           'lng': -79.55534628122035}],
#         'distance': 3253,
#         'postalCode': 'M9W 3W8',
#         'cc': 'CA',
#         'neighborhood': 'Rexdale',
#         'city': 'Etobicoke',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2290 Islington Ave. (Rexdale Blvd.)',
#          'Etobicoke ON M9W 3W8',
#          'Canada']},
#        'categories': [{'id': '4edd64a0c7ddd24ca188df1a',
#          'name': 'Fish & Chips Shop',
#          'pluralName': 'Fish & Chips Shops',
#          'shortName': 'Fish & Chips',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fishandchips_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae8b77cf964a520a8b121e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55731aee498e00fdf3fa3bc5',
#        'name': 'UP Express - Pearson T1 Station',
#        'location': {'address': 'Toronto Pearson International Airport',
#         'lat': 43.68270119408113,
#         'lng': -79.61308529382222,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.68270119408113,
#           'lng': -79.61308529382222}],
#         'distance': 3084,
#         'postalCode': 'L5P',
#         'cc': 'CA',
#         'neighborhood': 'Toronto Pearson International Airport',
#         'city': 'Mississauga',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Toronto Pearson International Airport',
#          'Mississauga ON L5P',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d129951735',
#          'name': 'Train Station',
#          'pluralName': 'Train Stations',
#          'shortName': 'Train Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55731aee498e00fdf3fa3bc5-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc87951dc55eee11d7ce8ac',
#        'name': 'Residence Inn Toronto Airport',
#        'location': {'address': '17 Reading Court',
#         'crossStreet': 'at Attwell Dr.',
#         'lat': 43.690119405110856,
#         'lng': -79.58792998457284,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.690119405110856,
#           'lng': -79.58792998457284}],
#         'distance': 1915,
#         'postalCode': 'M9W 7K7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['17 Reading Court (at Attwell Dr.)',
#          'Toronto ON M9W 7K7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '182991866'}},
#       'referralId': 'e-0-4bc87951dc55eee11d7ce8ac-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fdb75c0e4b0d1917d92b018',
#        'name': 'Wok of Asia',
#        'location': {'lat': 43.73415221096142,
#         'lng': -79.60577591204354,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.73415221096142,
#           'lng': -79.60577591204354}],
#         'distance': 3193,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fdb75c0e4b0d1917d92b018-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be452122457a593c40eaa15',
#        'name': 'Tim Hortons',
#        'location': {'address': '116 Queens Plate Dr',
#         'lat': 43.71465748224628,
#         'lng': -79.59371566772467,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.71465748224628,
#           'lng': -79.59371566772467}],
#         'distance': 880,
#         'postalCode': 'M9W 7K4',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['116 Queens Plate Dr',
#          'Etobicoke ON M9W 7K4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be452122457a593c40eaa15-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e68accf2271685ed98867f7',
#        'name': 'VeerPreet Auto Repairs',
#        'location': {'address': '6559 Airport Road',
#         'crossStreet': 'Derry & Airport Rd.',
#         'lat': 43.69589396171617,
#         'lng': -79.63139608277685,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.69589396171617,
#           'lng': -79.63139608277685}],
#         'distance': 3239,
#         'postalCode': 'L4V 1E5',
#         'cc': 'CA',
#         'city': 'Mississauga',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['6559 Airport Road (Derry & Airport Rd.)',
#          'Mississauga ON L4V 1E5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d124951735',
#          'name': 'Automotive Shop',
#          'pluralName': 'Automotive Shops',
#          'shortName': 'Automotive',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e68accf2271685ed98867f7-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbd615ea8cf76b015cfb1fd',
#        'name': 'Woodbine Racetrack',
#        'location': {'address': '555 Rexdale Blvd',
#         'crossStreet': 'at Hwy. 27',
#         'lat': 43.716673372932725,
#         'lng': -79.6049620534349,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.716673372932725,
#           'lng': -79.6049620534349}],
#         'distance': 1411,
#         'postalCode': 'M9W 5L2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['555 Rexdale Blvd (at Hwy. 27)',
#          'Toronto ON M9W 5L2',
#          'Canada']},
#        'categories': [{'id': '56aa371be4b08b9a8d573514',
#          'name': 'Racecourse',
#          'pluralName': 'Racecourses',
#          'shortName': 'Racecourse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_track_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbd615ea8cf76b015cfb1fd-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b30b0d7f964a520f2fa24e3',
#        'name': "Zet's Restaurant",
#        'location': {'address': '6445 Airport Rd.',
#         'crossStreet': 'btwn Orlando Dr. & American Dr.',
#         'lat': 43.693057296662545,
#         'lng': -79.62748804311175,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.693057296662545,
#           'lng': -79.62748804311175}],
#         'distance': 3092,
#         'postalCode': 'L4V 1E4',
#         'cc': 'CA',
#         'city': 'Mississauga',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['6445 Airport Rd. (btwn Orlando Dr. & American Dr.)',
#          'Mississauga ON L4V 1E4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b30b0d7f964a520f2fa24e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b466748f964a520d81f26e3',
#        'name': "Moxie's Classic Grill",
#        'location': {'address': '55 Reading Crt.',
#         'crossStreet': 'at Atwell Dr.',
#         'lat': 43.68991781115831,
#         'lng': -79.5907838255991,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.68991781115831,
#           'lng': -79.5907838255991}],
#         'distance': 1891,
#         'postalCode': 'M9W 7K7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['55 Reading Crt. (at Atwell Dr.)',
#          'Toronto ON M9W 7K7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b466748f964a520d81f26e3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c3484497cc0c9b69768f39a',
#        'name': '401 Diner',
#        'location': {'address': '2-24 Ronson Dr',
#         'lat': 43.700939740345575,
#         'lng': -79.56244301714327,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.700939740345575,
#           'lng': -79.56244301714327}],
#         'distance': 2624,
#         'postalCode': 'M9W 1B2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2-24 Ronson Dr',
#          'Toronto ON M9W 1B2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c3484497cc0c9b69768f39a-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be594a12468c92856310043',
#        'name': "Schuey's Bar and Grill",
#        'location': {'lat': 43.700943561076556,
#         'lng': -79.57543658325682,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.700943561076556,
#           'lng': -79.57543658325682}],
#         'distance': 1631,
#         'cc': 'CA',
#         'city': 'Toronto Division',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Toronto Division ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be594a12468c92856310043-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b97d2fcf964a5200d1835e3',
#        'name': 'Gourmet Express',
#        'location': {'address': '1735 Kipling Ave.',
#         'crossStreet': 'at Dixon Rd.',
#         'lat': 43.69311138097989,
#         'lng': -79.55729392261416,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.69311138097989,
#           'lng': -79.55729392261416}],
#         'distance': 3325,
#         'postalCode': 'M9R 2Y8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1735 Kipling Ave. (at Dixon Rd.)',
#          'Toronto ON M9R 2Y8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b97d2fcf964a5200d1835e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc67ef4b387d13a4c0fc2e8',
#        'name': 'The Vue',
#        'location': {'address': '195 Galaxy Blvd',
#         'lat': 43.677721171464704,
#         'lng': -79.58321654914884,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677721171464704,
#           'lng': -79.58321654914884}],
#         'distance': 3346,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['195 Galaxy Blvd', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d11f941735',
#          'name': 'Nightclub',
#          'pluralName': 'Nightclubs',
#          'shortName': 'Nightclub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc67ef4b387d13a4c0fc2e8-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59b8bfaaa6fe4d1e9176c881',
#        'name': 'DoubleTree by Hilton',
#        'location': {'address': '925 Dixon Road',
#         'lat': 43.68613569873045,
#         'lng': -79.5963321626187,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.68613569873045,
#           'lng': -79.5963321626187}],
#         'distance': 2301,
#         'postalCode': 'M9W 1J8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['925 Dixon Road',
#          'Toronto ON M9W 1J8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59b8bfaaa6fe4d1e9176c881-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '593901b1f62e090a8ea20add',
#        'name': 'Delta Hotels by Marriott Toronto Airport & Conference Centre',
#        'location': {'address': '655 Dixon Road',
#         'lat': 43.68899323056975,
#         'lng': -79.57790675791335,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.68899323056975,
#           'lng': -79.57790675791335}],
#         'distance': 2365,
#         'postalCode': 'M9W 1J3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['655 Dixon Road',
#          'Toronto ON M9W 1J3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-593901b1f62e090a8ea20add-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c7efd42171b224bcab30fb1',
#        'name': 'Sushi Ya',
#        'location': {'address': '621 Dixon Road',
#         'lat': 43.69036290634127,
#         'lng': -79.57596413416118,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.69036290634127,
#           'lng': -79.57596413416118}],
#         'distance': 2333,
#         'postalCode': 'M9W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['621 Dixon Road', 'Toronto ON M9W', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c7efd42171b224bcab30fb1-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7beea6f964a5206f742fe3',
#        'name': 'Sandman Signature Hotel Toronto Airport',
#        'location': {'address': '55 Reading Court',
#         'lat': 43.689918376498554,
#         'lng': -79.5904267486086,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.689918376498554,
#           'lng': -79.5904267486086}],
#         'distance': 1896,
#         'postalCode': 'M9W 7K7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['55 Reading Court',
#          'Toronto ON M9W 7K7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7beea6f964a5206f742fe3-29'}]}]}}

# %% [markdown]
# # Parse the results to select any restaurant out of the 182 restaurants as mentioned in above results

# %%
res=results['response']['groups'][0]['items']
res[2]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4b9924aaf964a5205e6435e3',
#   'name': 'Golden Asian',
#   'location': {'address': '123 - #7 Rexdale Blvd.',
#    'lat': 43.71124779631982,
#    'lng': -79.56596849779808,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.71124779631982,
#      'lng': -79.56596849779808}],
#    'distance': 2314,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['123 - #7 Rexdale Blvd.', 'Toronto ON', 'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d142941735',
#     'name': 'Asian Restaurant',
#     'pluralName': 'Asian Restaurants',
#     'shortName': 'Asian',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-4b9924aaf964a5205e6435e3-2'}

# %% [markdown]
# # converting the above JSON to dataframe

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

    df2 = json_normalize(res) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in df2.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = df2.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                                     name          categories  \
# 0                               Fortinos       Grocery Store
# 1                        Mandarin Buffet  Chinese Restaurant
# 2                           Golden Asian    Asian Restaurant
# 3  The Keg Steakhouse + Bar - Dixon Road          Restaurant
# 4                        Tre Rose Bakery              Bakery
#
#                   address  cc       city country          crossStreet  \
# 0     330 Queens Plate Dr  CA  Etobicoke  Canada            at Hwy 27
# 1     200 Queens Plate Dr  CA    Rexdale  Canada            at Hwy 27
# 2  123 - #7 Rexdale Blvd.  CA    Toronto  Canada                  NaN
# 3          927 Dixon Road  CA    Toronto  Canada                  NaN
# 4     2098 Kipling avenue  CA    Toronto  Canada  Kipling and rexdale
#
#    distance                                   formattedAddress  \
# 0      1645  [330 Queens Plate Dr (at Hwy 27), Etobicoke ON...
# 1      1515  [200 Queens Plate Dr (at Hwy 27), Rexdale ON M...
# 2      2314       [123 - #7 Rexdale Blvd., Toronto ON, Canada]
# 3      2288       [927 Dixon Road, Toronto ON M9W 1J8, Canada]
# 4      2268  [2098 Kipling avenue (Kipling and rexdale), To...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.721438, 'lng':...  43.721438 -79.596291
# 1  [{'label': 'display', 'lat': 43.7203596, 'lng'...  43.720360 -79.594387
# 2  [{'label': 'display', 'lat': 43.71124779631982...  43.711248 -79.565968
# 3  [{'label': 'display', 'lat': 43.68632856455964...  43.686329 -79.597353
# 4  [{'label': 'display', 'lat': 43.7164913472275,...  43.716491 -79.569288
#
#   neighborhood postalCode state                        id
# 0          NaN    M9W 7J7    ON  4ba50113f964a52018cf38e3
# 1          NaN    M9W 6Y9    ON  4b5f8a3df964a52062c029e3
# 2          NaN        NaN    ON  4b9924aaf964a5205e6435e3
# 3          NaN    M9W 1J8    ON  4ad7719cf964a520870a21e3
# 4          NaN    M9W 4K5    ON  4dad993e6e81d745d744c5fb

# %% [markdown]
# # Plotting all the resturants in the neighborhood

# %%
venues_map = folium.Map(location=[LATITUDE, LONGITUDE], zoom_start=12) # generate map centred around the the location postal code I picked

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [LATITUDE, LONGITUDE],
    radius=10,
    color='red',
    popup='Neighborhood M9W',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add all the restaurants as green circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='purple',
        popup=label,
        fill = True,
        fill_color='purple',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
